# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt
import re
import os
import pandas as pd

pytesseract.pytesseract.tesseract_cmd = \
    r'C:\Program Files\Tesseract-OCR\tesseract.exe'


current_location = os.getcwd()

VIN_No = []
CH_No = []
ENO_No = []
REG_No = []
REG_DATE = []
MFG_DATE=[]
FILE_NAMES=[]

Flag_REGN = False
Flag_ENO = False
Flag_CH_NO = False
Flag_REG_DATE = False
Flag_MFG_DATE = False

REGN=''
EN=''
CH=''
RD=''
MD=''

# %%
 

for j in os.listdir(current_location): 
        
        
        if j.endswith('.jpg'):
            
            FILE_NAMES.append(j)
            
            print(j)
            image=Image.open(j)
            (length_x, width_y) = image.size
            factor = min(1, float(1024.0 / length_x))
            size = (int(factor * length_x), int(factor * width_y))
            im_resized = image.resize(size, Image.ANTIALIAS)
            
          
            text=pytesseract.image_to_string(image).replace('/n','').upper().split()

           
            
            

            for i in range(0,len(text)):

                        if text[i] == 'REGN' and text[i+2]=='NO':
                            print(text[i+4])
                            value=text[i+4]
                            REGN=value
                            Flag_REGN=True
                      
                        if text[i] == 'REGN.' and text[i+1]=='NO':
                            print(1)
                            print(text[i+3])
                            value=text[i+3]
                            REGN=value
                            Flag_REGN=True
                         
                        if text[i] == 'REGN.' and text[i+1]=='NO:':
                            print(1)
                            print(text[i+2])
                            value=text[i+2]
                            REGN=value
                            Flag_REGN=True
                         
                        if text[i] == 'REGN.' and text[i+1]=='NO:':
                            print(1)
                            print(text[i+2])
                            value=text[i+2]
                            REGN=value
                            Flag_REGN=True 

                        if text[i]=='REG.' and text[i+1]=='DT:' or text[i]=='REG.' and text[i+1]=='DT:' or text[i]=='REG.' and text[i+1]=='DT':
                            print(2)
                            print(text[i+2])
                            value=text[i+2]
                            RD=value
                            Flag_REG_DATE=True
                        
                        if text[i]=='REGISTRATION' and text[i+1]=='NO.':
                            print(2)
                            print(text[i+2])
                            value=text[i+2]
                            REGN=value
                            Flag_REGN=True
                    
                                 
            
                        if text[i]=='REGN' and text[i+1]=='.' :
                            print(2)
                            print(text[i+3])
                            value=text[i+3]
                            RD=value
                            Flag_REG_DATE=True
                        
                        
                        if text[i]=='REGN' and text[i+1]=='DT:':
                            print(2)
                            print(text[i+2])
                            value=text[i+2]
                            RD=value
                            Flag_REG_DATE=True
                            

                        if text[i]=='REGN' and text[i+1]=='.' :
                            print(2)
                            print(text[i+3])
                            value=text[i+3]
                            RD=value
                            Flag_REG_DATE=True
                        
                            
                         
                        if text[i]=='REGN' and text[i+1]=='.' and text[i+2]=='NO:' :
                            print(2)
                            print(text[i+3])
                            value=text[i+3]
                            REGN=value
                            Flag_REGNE=True
                    
                            
                            
                            
                       

                        if text[i]=='ENO' and text[i+1]==':':
                            print(3)
                            print(text[i+2])
                            value=text[i+2]
                            EN=value
                            Flag_ENO=True
                        
                        if text[i]=="ENO":
                            print(3)
                            print(text[i+2])
                            value=text[i+2]
                            EN=value
                            Flag_ENO=True
                          
                        
                        if text[i]=="ENGINE":
                            print(3)
                            print(text[i+1])
                            value=text[i+1]
                            EN=value
                            Flag_ENO=True
                            
                        
                        if text[i]=="ENGINE" and text[i+1]=='NO.':
                            print(3)
                            print(text[i+2])
                            value=text[i+2]
                            EN=value
                            Flag_ENO=True
                            
                            

                        if text[i]=='CH.NO' and text[i+1]==':' or text[i]=='CH.' and text[i+1]=='NO':
                            print(4)
                            print(text[i+2])
                            CH=text[i+2]
                            Flag_CH_NO=True
                        
                        if text[i]=='CH.' and text[i+1]=='NO':
                            print(4)
                            print(text[i+3])
                            CH=text[i+3]
                            Flag_CH_NO=True
                         
                        if text[i]=='CH.NO' :
                            print(4)
                            print(text[i+2])
                            CH=text[i+2]
                            Flag_CH_NO=True
                            
                            
                        if text[i]=='CHASIS' and text[i+1]=='NO.' :
                            print(4)
                            print(text[i+2])
                            CH=text[i+2]
                            Flag_CH_NO=True
                        
                            
                        
                        if text[i]=='CHINO' and text[i+1]==':':
                            print(4)
                            print(text[i+2])
                            CH=text[i+2]
                            Flag_CH_NO=True
                        
                        if text[i]=='CH' and text[i+1]=='NO':
                            print(4)
                            print(text[i+4])
                            CH=text[i+4]
                            Flag_CH_NO=True
                        

                        if text[i]=='CHASSIS' and text[i+1]=='NO.':
                            print(4)
                            print(text[i+2])
                            CH=text[i+2]
                            Flag_CH_NO=True
                        
                        

                        if text[i]=='MFG.' and text[i+1]=='DT.':
                            print(5)
                            print(text[i+3])
                            MD=text[i+3]        
                            Flag_MFG_DATE=True
                        
                        if text[i]=='MFG' and text[i+1]=='DT':
                            print(5)
                            print(text[i+2])
                            MD=text[i+2]        
                            Flag_MFG_DATE=True
                        
                        if text[i]=='MFG.DT.' and text[i+1]=='DT':
                            print(5)
                            print(text[i+2])
                            MD=text[i+2]        
                            Flag_MFG_DATE=True
                            
                                                    
                        if text[i]=='MFG.DT.' and text[i+1]==':':
                            print(5)
                            print(text[i+2])
                            MD=text[i+2]        
                            Flag_MFG_DATE=True

                            




        else:continue

        if Flag_REGN==True: REG_No.append(REGN)
        else :  REG_No.append(np.nan) 

        if Flag_REG_DATE==True: REG_DATE.append(RD)
        else :  REG_DATE.append(np.nan) 

        if Flag_CH_NO==True: CH_No.append(CH)
        else :  CH_No.append(np.nan) 

        if Flag_ENO==True: ENO_No.append(EN)
        else :  ENO_No.append(np.nan) 


        if Flag_MFG_DATE==True: MFG_DATE.append(MD)
        else :  MFG_DATE.append(np.nan)
# Out:
# txt_mudit_b11_11599.jpg
# DL9CAC6215
# 2
# :
# 2
# :
# 2
# 24/42/2012
# 4
# MA3FHEB1S00358580
# 4
# MA3FHEB1S00358580
# 3
# D13A0338461
# 3
# D13A0338461
# txt_mudit_b11_12.jpg
# 1
# DL2CAT9109"”
# 2
# 21/07/2015
# 4
# MA3ETDE1S00218363
# 3
# 7567094
# 3
# 7567094
# 5
# 07/2015
# txt_mudit_b11_1328.jpg
# 4
# MA3EYD81S00765439
# txt_mudit_b11_1330.jpg
# txt_mudit_b11_1332.jpg
# 2
# HR49D
# 4
# MA3FJEB1S00404062
# 3
# 013A2235550
# txt_mudit_b11_1334.jpg
# 4
# MA3ELMG1800384268
# 3
# K14BN
# txt_mudit_b11_1337.jpg

# %%
print(REG_No)
print(REG_DATE)
print(ENO_No)
print(CH_No)
print(MFG_DATE)
VIN_No=CH_No

# %%
data=FILE_NAMES,REG_No,REG_DATE,ENO_No,CH_No,MFG_DATE

data=pd.DataFrame(data,dtype='object')

data=data.T

data=data.rename(columns={0:'File_name',1:'Registartion Number',2:"Registration Date",3:"Engine Number",4:'MFG date',5:'Vin_number'})

# %%
data

# %% [markdown]
# VIN_No = []
# CH_No = []
# ENO_No = []
# REG_No = []
# REG_DATE = []
# MFG_DATE=[]
# FILE_NAMES=[]
#
# Flag_REGN = False
# Flag_ENO = False
# Flag_CH_NO = False
# Flag_REG_DATE = False
# Flag_MFG_DATE = False
#
# REGN=''
# EN=''
# CH=''
# RD=''
# MD=''
#
#
# for i in os.listdir(current_location):
#
#
#         if i.endswith('.jpg')==True:
#
#             FILE_NAMES.append(i)
#             image=Image.open(i)
#             (length_x, width_y) = image.size
#             factor = min(1, float(1024.0 / length_x))
#             size = (int(factor * length_x), int(factor * width_y))
#             im_resized = image.resize(size, Image.ANTIALIAS)
#             text=pytesseract.image_to_string(image).replace('/n','').upper().split()
#
#             for i in range(0,len(text)):
#
#                         if text[i] == 'REGN' and text[i+2]=='NO':
#                             print(1)
#                             print(text[i+4])
#                             value=text[i+4]
#                             REGN=value
#                             Flag_REGN=True
#
#                         elif text[i] == 'REGN.' and text[i+1]=='NO':
#                             print(1)
#                             print(text[i+3])
#                             value=text[i+3]
#                             REGN=value
#                             Flag_REGN=True
#
#                         elif text[i] == 'REGN.' and text[i+1]=='NO:':
#                             print(1)
#                             print(text[i+2])
#                             value=text[i+2]
#                             REGN=value
#                             Flag_REGN=True
#
#                         elif text[i] == 'REGN.' and text[i+1]=='NO:':
#                             print(1)
#                             print(text[i+2])
#                             value=text[i+2]
#                             REGN=value
#                             Flag_REGN=True
#
#                         elif text[i]=='REG.' and text[i+1]=='DT:' or text[i]=='REG.' and text[i+1]=='DT:' or text[i]=='REG.' and text[i+1]=='DT':
#                             print(2)
#                             print(text[i+2])
#                             value=text[i+2]
#                             RD=value
#                             Flag_REG_DATE=True
#
#                         elif text[i]=='REGISTRATION' and text[i+1]=='NO.':
#                             print(2)
#                             print(text[i+2])
#                             value=text[i+2]
#                             REGN=value
#                             Flag_REGN=True
#
#
#
#                         elif text[i]=='REGN' and text[i+1]=='.' :
#                             print(2)
#                             print(text[i+3])
#                             value=text[i+3]
#                             RD=value
#                             Flag_REG_DATE=True
#
#
#                         elif text[i]=='REGN' and text[i+1]=='DT:':
#                             print(2)
#                             print(text[i+2])
#                             value=text[i+2]
#                             RD=value
#                             Flag_REG_DATE=True
#
#
#                         elif text[i]=='REGN' and text[i+1]=='.' :
#                             print(2)
#                             print(text[i+3])
#                             value=text[i+3]
#                             RD=value
#                             Flag_REG_DATE=True
#
#
#
#                         elif text[i]=='REGN' and text[i+1]=='.' and text[i+2]=='NO:' :
#                             print(2)
#                             print(text[i+3])
#                             value=text[i+3]
#                             REGN=value
#                             Flag_REGNE=True
#
#
#                         elif text[i]=='ENO' and text[i+1]==':':
#                             print(3)
#                             print(text[i+2])
#                             value=text[i+2]
#                             EN=value
#                             Flag_ENO=True
#
#                         elif text[i]=="ENO":
#                             print(3)
#                             print(text[i+2])
#                             value=text[i+2]
#                             EN=value
#                             Flag_ENO=True
#
#
#                         elif text[i]=="ENGINE":
#                             print(3)
#                             print(text[i+1])
#                             value=text[i+1]
#                             EN=value
#                             Flag_ENO=True
#                             'ENGINE', 'NO.', 'F10DN4452456'
#
#                         elif text[i]=="ENGINE" and text[i+1]=='NO.':
#                             print(3)
#                             print(text[i+2])
#                             value=text[i+2]
#                             EN=value
#                             Flag_ENO=True
#
#
#
#                         elif text[i]=='CH.NO' and text[i+1]==':' or text[i]=='CH.' and text[i+1]=='NO':
#                             print(4)
#                             print(text[i+2])
#                             CH=text[i+2]
#                             Flag_CH_NO=True
#
#                         elif text[i]=='CH.' and text[i+1]=='NO':
#                             print(4)
#                             print(text[i+3])
#                             CH=text[i+3]
#                             Flag_CH_NO=True
#
#                         elif text[i]=='CH.NO' :
#                             print(4)
#                             print(text[i+2])
#                             CH=text[i+2]
#                             Flag_CH_NO=True
#
#
#                         elif text[i]=='CHASIS' and text[i+1]=='NO.' :
#                             print(4)
#                             print(text[i+2])
#                             CH=text[i+2]
#                             Flag_CH_NO=True
#
#
#
#                         elif text[i]=='CHINO' and text[i+1]==':':
#                             print(4)
#                             print(text[i+2])
#                             CH=text[i+2]
#                             Flag_CH_NO=True
#
#                         elif text[i]=='CH' and text[i+1]=='NO':
#                             print(4)
#                             print(text[i+4])
#                             CH=text[i+4]
#                             Flag_CH_NO=True
#
#
#                         elif text[i]=='CHASSIS' and text[i+1]=='NO.':
#                             print(4)
#                             print(text[i+2])
#                             CH=text[i+2]
#                             Flag_CH_NO=True
#
#
#
#                         elif text[i]=='MFG.' and text[i+1]=='DT.':
#                             print(5)
#                             print(text[i+3])
#                             MD=text[i+3]
#                             Flag_MFG_DATE=True
#
#                         elif text[i]=='MFG' and text[i+1]=='DT':
#                             print(5)
#                             print(text[i+2])
#                             MD=text[i+2]
#                             Flag_MFG_DATE=True
#
#                         elif text[i]=='MFG.DT.' and text[i+1]=='DT':
#                             print(5)
#                             print(text[i+2])
#                             MD=text[i+2]
#                             Flag_MFG_DATE=True
#
#
#                         elif text[i]=='MFG.DT.' and text[i+1]==':':
#                             print(5)
#                             print(text[i+2])
#                             MD=text[i+2]
#                             Flag_MFG_DATE=True
#
#
#
#
#
#         else: pass
#
#
#
#
#         if Flag_REGN==True: REG_No.append(REGN)
#         else :  REG_No.append(np.nan)
#
#         if Flag_REG_DATE==True: REG_DATE.append(RD)
#         else :  REG_DATE.append(np.nan)
#
#         if Flag_CH_NO==True: CH_No.append(CH)
#         else :  CH_No.append(np.nan)
#
#         if Flag_ENO==True: ENO_No.append(EN)
#         else :  ENO_No.append(np.nan)
#
#
#         if Flag_MFG_DATE==True: MFG_DATE.append(MD)
#         else :  MFG_DATE.append(np.nan)
